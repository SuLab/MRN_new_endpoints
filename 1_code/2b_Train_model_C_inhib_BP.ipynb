# %%
import os
import pickle
import numpy as np
import pandas as pd
from time import time
from pathlib import Path
from tqdm.notebook import tqdm
import data_tools.graphs as gt
from hetnet_ml.extractor import MatrixFormattedGraph, piecewise_extraction
# Out:
# /opt/mmayers/software/anaconda3/envs/ml/lib/python3.6/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import utils

# %%
param_file = 'CiBP_param.json'
param_file = Path('../0_data/manual').resolve().joinpath(param_file)

# %%
# Model training is param #3 (network is 1, hyperparmas is 2)
out_dir = utils.read_data_param(param_file)[2]

# %%
tgt_node, tgt_edge = utils.load_targets(param_file)

# %%
nodes, edges = utils.load_network(param_file)

# %%
best_param, features = utils.load_hyperparameters(param_file)

# %%
print('{:,} Nodes'.format(len(nodes)))
print('{:,} Edges'.format(len(edges)))
# Out:
# 250,035 Nodes
# 9,652,116 Edges

# %%
best_param
# Out:
# {'C': 0.0014351562349983393,
#  'l1_ratio': 0.9871439566131671,
#  'w': 0.5665616931869023}

# %% [markdown]
# ## Routine for extracting information

# %%
# %%time
mg = MatrixFormattedGraph(nodes, edges, 'ChemicalSubstance', tgt_node, max_length=4, w=best_param['w'], n_jobs=32)
# Out:
# Processing node and edge data...
# Initializing metagraph...
# Generating adjacency matrices...
# 100%|██████████| 68/68 [00:56<00:00,  1.21it/s]
# Determining degrees for each node and metaedge
# 100%|██████████| 68/68 [00:26<00:00,  2.54it/s]
# Weighting matrices by degree with dampening factor 0.5665616931869023...
# 100%|██████████| 68/68 [00:00<00:00, 120.86it/s]
# CPU times: user 40.9 s, sys: 18.7 s, total: 59.6 s
# Wall time: 2min 23s

# %%
# Ensure that we have float64 matrices"
mg.degree_weighted_matrices[tgt_edge.split('_')[-1]]
# Out:
# <40766x21065 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39706 stored elements in Compressed Sparse Column format>

# %% [markdown]
# #### Right away lets get the true positives as we will need them later

# %%
pos_tups = (mg.edge_df.query('type == @tgt_edge')[['start_id', 'end_id']]
                      .apply(tuple, axis=1)
                      .tolist())
pos_tups = set(pos_tups)

# %%
ref_c = nodes.dropna(subset=['source'])['id'].tolist()

# %%
neg_frac = 0.1
rs = 20201117

tgt_comps = set(edges.query('type == @tgt_edge')['start_id'])
# Sample the negatives and subsample, but not Reframe negatvies... keep them as 'Unknown'
keep_comps = set(nodes.query('id not in @tgt_comps and id not in @ref_c and label == "ChemicalSubstance"')
                                    .sample(frac=neg_frac, random_state=rs)['id'])
# Merge togetehr
keep_comps = sorted(list(keep_comps | tgt_comps))

# Get our target type 
tgt_endp = set(edges.query('type == @tgt_edge')['end_id'])
# Sample the negatives and subsample cv
keep_endp = set(nodes.query('label == @tgt_node and id not in @tgt_endp')
                    .sample(frac=neg_frac, random_state=rs+1)['id'])
# Merge together
keep_endp = sorted(list(keep_endp | tgt_endp))

# %%
print(len(keep_comps), len(keep_endp))
print('{:,}'.format(len(keep_comps) * len(keep_endp)))
print('{:,}'.format(len(keep_comps) * len(keep_endp) * len(features)))
# Out:
# 9242 5052
# 46,690,584
# 16,341,704,400

# %%
def display_time(seconds):
    result = []
    
    intervals = (
    ('weeks', 604800),  # 60 * 60 * 24 * 7
    ('days', 86400),    # 60 * 60 * 24
    ('hours', 3600),    # 60 * 60
    ('minutes', 60),
    ('seconds', 1),
    )


    for name, count in intervals:
        value = seconds // count
        if value:
            seconds -= value * count
            if value == 1:
                name = name.rstrip('s')
            result.append("{:1.0f} {}".format(value, name))
    return ', '.join(result)

# %%
from data_tools.ml import get_model_coefs, MeanScaledArcsinhTransformer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MaxAbsScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
enet_params = {k: v for k, v in best_param.items() if k != 'w'}

post_extraction_pipeline = Pipeline(
    [('transformer', MeanScaledArcsinhTransformer()),
     ('maxabs_scale', MaxAbsScaler()),
     ('e_net', LogisticRegression(penalty='elasticnet', solver='saga', max_iter=5000,
                                  random_state=rs+11, **enet_params))], verbose=True)

# %%
# %%time

start = time()

(pairs, out_mp), dwpc = mg.extract_dwpc(metapaths=features, start_nodes=keep_comps, end_nodes=keep_endp, 
                   return_sparse=True, sparse_df=False, verbose=True, n_jobs=30)
# Out:
# Preparing function arguments...
# Calculating DWPCs...
# 100%|██████████| 350/350 [00:35<00:00,  9.97it/s]
# Reshaping Result Matrices...
# 100%|██████████| 350/350 [01:01<00:00,  5.71it/s]
# Stacking columns...
# CPU times: user 1min 24s, sys: 33.5 s, total: 1min 58s
# Wall time: 2min 6s

# %%
print('Getting Target Values')
y = []
for row in tqdm(pairs.itertuples(), total=len(pairs)):
    # pos_tups defined several cells above
    if set([(row.chemicalsubstance_id, getattr(row, tgt_node.lower()+'_id'))]) & pos_tups:
        y.append(1)
    else:
        y.append(0)

y = np.array(y)
pairs['status'] = y

print('Getting training subset')
# subset so that we're training only with nonzero dwpc rows
# Get the training examples that have metapaths
nz_index = pairs[dwpc.getnnz(1)>0].index
# have the number of postivies to get 100x this for the negatives.
n_pos = pairs['status'].sum()
# Sample the nonzero negative examples at a rate of 100x the positive samples
neg_index = pairs.loc[nz_index].query('status == 0').sample(n=100*n_pos, random_state=rs+10).sort_index().index
# and of course take the training postivies
pos_index = pairs.query('status == 1').index
# Union the two
train_index = pos_index.union(neg_index)

# Fit the model and get results
print('Training Model')
post_extraction_pipeline.fit(dwpc[train_index, :], y[train_index])
# Out:
# Getting Target Values
# HBox(children=(FloatProgress(value=0.0, max=46690584.0), HTML(value='')))
# Getting training subset
# Training Model
# [Pipeline] ....... (step 1 of 3) Processing transformer, total=  31.7s
# [Pipeline] ...... (step 2 of 3) Processing maxabs_scale, total=   1.7s
# [Pipeline] ............. (step 3 of 3) Processing e_net, total=10.6min
# Pipeline(steps=[('transformer',
#                  <data_tools.ml.MeanScaledArcsinhTransformer object at 0x7fc7cf856eb8>),
#                 ('maxabs_scale', MaxAbsScaler()),
#                 ('e_net',
#                  LogisticRegression(C=0.0014351562349983393,
#                                     l1_ratio=0.9871439566131671, max_iter=5000,
#                                     penalty='elasticnet', random_state=20201128,
#                                     solver='saga'))],
#          verbose=True)

# %%
# Get coef
print('Getting Model Coef')
trans_dwpc = post_extraction_pipeline[1].transform(post_extraction_pipeline[0].transform(dwpc[train_index, :]))

coef = get_model_coefs(post_extraction_pipeline[-1], trans_dwpc, features).sort_values('coef', ascending=False)

print('Training took: ' + display_time(time() - start))
print('\n\n')
# Out:
# Getting Model Coef
# Training took: 16 minutes, 33 seconds

# %%
utils.save_model(post_extraction_pipeline, out_mp, coef, out_dir)

# %%
coef.head(10)
# Out:
#               feature      coef      zcoef
# 278   CafGpoPWawCinBP    3.5791   0.365881
# 277   CafGpoPWawCafBP    2.4787   0.250402
# 276    CafGpoPWawCaBP   1.99584   0.240424
# 79     CaBPpoGrxCinBP  0.769888  0.0530822
# 131    CinBPpoGrxCaBP  0.691443   0.053235
# 23        CafBPpoGrBP  0.636232  0.0389388
# 148  CinBPpoPWawCinBP  0.579179  0.0459198
# 25       CinBPpoCafBP  0.568841   0.025543
# 78     CaBPpoGrxCafBP  0.537691  0.0398573
# 18       CafBPpoCinBP  0.459539  0.0187964

# %%
len(coef.query('coef != 0')) - 1
# Out:
# 26

# %%
# %%time

start = time()
        
# Fit the model and get results
print('Getting Probabilities')
y_proba = post_extraction_pipeline.predict_proba(dwpc)[:, 1]
# Out:
# Getting Probabilities
# CPU times: user 6min 31s, sys: 58.5 s, total: 7min 29s
# Wall time: 7min 29s

# %%
# Get metrics
print('Metrics on training data')
roc_auc = roc_auc_score(y, y_proba)
avg_prec = average_precision_score(y, y_proba)
print('AUROC: {:1.4f}'.format(roc_auc))
print('AUPR: {:1.4f}'.format(avg_prec))
# Out:
# Metrics on training data
# AUROC: 0.9467
# AUPR: 0.1580

# %%
pairs['status'] = y
pairs['proba'] = y_proba

# Save results
pairs.to_csv(out_dir.joinpath('results.csv'), index=False)

print('Eval took: ' + display_time(time() - start))
print('\n\n')
# Out:
# Eval took: 10 minutes, 11 seconds

# %% [markdown]
# ## Load back in all the results and plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from data_tools import plotting as pt

# %%
pt.graph_single_roc(y, y_proba, 'Training Data')
pt.graph_roc_boilerplate('Final Model - ROC - All Pairs');

# %%
pt.graph_single_prc(y, y_proba, 'Training Data')
pt.graph_prc_boilerplate('Final Model - Precision Recall -\nAll Pairs');

# %%
pt.graph_single_roc(y[nz_index], y_proba[nz_index], 'Training Data')
pt.graph_roc_boilerplate('Final Model - ROC - Non-zero Pairs');

# %%
pt.graph_single_prc(y[nz_index], y_proba[nz_index], 'Training Data')
pt.graph_prc_boilerplate('Final Model - Precision Recall -\nNon-zero Pairs');

# %%
id_to_name = nodes.set_index('id')['name'].to_dict()
pairs['chem'] = pairs['chemicalsubstance_id'].map(id_to_name)
pairs['bp'] = pairs['biologicalprocessoractivity_id'].map(id_to_name)

# %%
pairs.head(10)
# Out:
#   chemicalsubstance_id biologicalprocessoractivity_id  status     proba  \
# 0         CHEBI:100148                     GO:0000002       0  0.001347
# 1         CHEBI:100148                     GO:0000003       0  0.001347
# 11201305          CHEBI:37537                     GO:0008283       1
# 44539453         MESH:D014028                     GO:0008283       1
# 43730927         MESH:D008070                     GO:0006915       1
# 12130667          CHEBI:41879                     GO:0006915       1
# 6659557           CHEBI:28088                     GO:0008283       1
# 3274717           CHEBI:15367                     GO:0008283       1
# 14793071          CHEBI:53795                     GO:0006915       1
# 12661326          CHEBI:45713                     GO:0008219       1
# 10675691          CHEBI:35456                     GO:0006915       1
# 11201099          CHEBI:37537                     GO:0006915       1
# 11958899           CHEBI:4031                     GO:0006915       1
# 44109827         MESH:D010936                     GO:0006915       1
# 9417759           CHEBI:33216                     GO:0006979       1
# 7558806           CHEBI:29678                     GO:0008219       1
# 44539247         MESH:D014028                     GO:0006915       1
# 9417950           CHEBI:33216                     GO:0008284       1
# 7114031           CHEBI:28748                     GO:0006915       1
# 9417941           CHEBI:33216                     GO:0008217       0
#
#              proba                             chem  \
# 9417949   0.995213                      bisphenol A
# 9417743   0.994336                      bisphenol A
# 7558813   0.991845                  sodium arsenite
# 46145989  0.991533         Tetrachlorodibenzodioxin
# 7558607   0.991410                  sodium arsenite
# 12661333  0.991122                trans-resveratrol
# 9417942   0.991116                      bisphenol A
# 12661127  0.990315                trans-resveratrol
# 7614385   0.990197                   benzo[a]pyrene
# 11888377  0.990139                    valproic acid
# 7861933   0.989541               diarsenic trioxide
# 23573653  0.988959                        robinetin
# 3875905   0.988927                 17beta-estradiol
# 43200673  0.988677                     Dietary Fats
# 7417357   0.988666                       synephrine
# 46145783  0.988356         Tetrachlorodibenzodioxin
# 7861727   0.988320               diarsenic trioxide
# 12130873  0.988017                    dexamethasone
# 11888171  0.987757                    valproic acid
# 43200467  0.987260                     Dietary Fats
# 11959105  0.987233                    cyclosporin A
# 7614179   0.987224                   benzo[a]pyrene
# 23573447  0.987149                        robinetin
# 7417151   0.986729                       synephrine
# 14793277  0.986469                   (R)-amlodipine
# 9418363   0.986367                      bisphenol A
# 10675897  0.985901               cadmium dichloride
# 7114237   0.985822                      doxorubicin
# 43731133  0.985735              Lipopolysaccharides
# 3875699   0.985604                 17beta-estradiol
# 8468173   0.985451             ethynodiol diacetate
# 44110033  0.985386                   Plant Extracts
# 11201305  0.985254  phorbol 13-acetate 12-myristate
# 44539453  0.984991          Tobacco Smoke Pollution
# 43730927  0.984758              Lipopolysaccharides
# 12130667  0.984369                    dexamethasone
# 6659557   0.984287                        genistein
# 3274717   0.984231          all-trans-retinoic acid
# 14793071  0.984061                   (R)-amlodipine
# 12661326  0.983642                trans-resveratrol
# 10675691  0.983622               cadmium dichloride
# 11201099  0.983614  phorbol 13-acetate 12-myristate
# 11958899  0.983596                    cyclosporin A
# 44109827  0.983313                   Plant Extracts
# 9417759   0.983021                      bisphenol A
# 7558806   0.982904                  sodium arsenite
# 44539247  0.982186          Tobacco Smoke Pollution
# 9417950   0.982075                      bisphenol A
# 7114031   0.981975                      doxorubicin
# 9417941   0.981902                      bisphenol A
#
#                                                  bp
# 46145981  0.952362                           Tetrachlorodibenzodioxin
# 9417742   0.952268                                        bisphenol A
# 9417714   0.951895                                        bisphenol A
# 6679559   0.951645                                tetracarbonylnickel
# 9251027   0.951292                                     pirinixic acid
# 3875897   0.951240                                   17beta-estradiol
# 9418581   0.951143                                        bisphenol A
# 3259355   0.950952                                            choline
# 13171578  0.950738                                         endosulfan
#
#                                                     bp
# 9417941                   regulation of blood pressure
# 8467967                              apoptotic process
# 9419386                               vasoconstriction
# 9417598                    apoptotic DNA fragmentation
# 7684907                              apoptotic process
# 46146403                       lipid catabolic process
# 9418687                           cell differentiation
# 3557423                              apoptotic process
# 9419387                                   vasodilation
# 13171379                             apoptotic process
# 8468166                                     cell death
# 8149897                         cellular proliferation
# 22795439                             apoptotic process
# 11888791                       lipid catabolic process
# 34788887                             apoptotic process
# 11888378     positive regulation of cell proliferation
# 9241129                         cellular proliferation
# 3876319                        lipid catabolic process
# 9417112                       regulation of heart rate
# 45115175                             apoptotic process
# 7614652              positive regulation of cell death
# 43200665                  regulation of blood pressure
# 3926425                         cellular proliferation
# 9417684               cholesterol biosynthetic process
# 43200940             positive regulation of cell death
# 10130274                                    cell death
# 22431695                             apoptotic process
# 3557622                                     cell death
# 12661325                  regulation of blood pressure
# 22795638                                    cell death
# 24407027                             apoptotic process
# 45019393                        cellular proliferation
# 3259561                         cellular proliferation
# 7559275                                 cell migration
# 12660982                   apoptotic DNA fragmentation
# 12332946                                    cell death
# 44842573                        cellular proliferation
# 46149523  reactive oxygen species biosynthetic process
# 7614377                   regulation of blood pressure
# 7417358      positive regulation of cell proliferation
# 34789086                                    cell death
# 46145981                  regulation of blood pressure
# 9417742                                      autophagy
# 9417714                                  ion transport
# 6679559                              apoptotic process
# 9251027                              apoptotic process
# 3875897                   regulation of blood pressure
# 9418581                     calcium-mediated signaling
# 3259355                              apoptotic process
# 13171578                                    cell death

# %%
pairs.query('status == 0').drop_duplicates(subset=['chemicalsubstance_id']).head(50)
# Out:
#          chemicalsubstance_id biologicalprocessoractivity_id  status  \
# 9417941           CHEBI:33216                     GO:0008217       0
# 8467967           CHEBI:31580                     GO:0006915       0
# 7684907           CHEBI:30052                     GO:0006915       0
# 46146403      UNII:OHF2F5C0ZH                     GO:0016042       0
# 3557423           CHEBI:15930                     GO:0006915       0
# 13171379           CHEBI:4791                     GO:0006915       0
# 8149897           CHEBI:31206                     GO:0008283       0
# 22795439           CHEBI:8502                     GO:0006915       0
# 11888791          CHEBI:39867                     GO:0016042       0
# 34788887         MESH:C023035                     GO:0006915       0
# 9241129           CHEBI:32497                     GO:0008283       0
# 3876319           CHEBI:16469                     GO:0016042       0
# 45115175         MESH:D037742                     GO:0006915       0
# 7614652           CHEBI:29865                     GO:0010942       0
# 43200665         MESH:D004041                     GO:0008217       0
# 3926425           CHEBI:16503                     GO:0008283       0
# 10130274          CHEBI:34679                     GO:0008219       0
# 22431695          CHEBI:83732                     GO:0006915       0
# 12661325          CHEBI:45713                     GO:0008217       0
# 4280058   0.949397                                       progesterone
# 3183575   0.949226               tris(1,3-dichloro-2-propyl)phosphate
# 46034845  0.949175                           pentabromodiphenyl ether
# 7861925   0.948627                                 diarsenic trioxide
# 7028353   0.947560                                         acrylamide
# 43205718  0.947500                                 Diethylnitrosamine
# 2764259   0.946306                  3,4-methylenedioxymethamphetamine
# 23573486  0.946136                                          robinetin
# 5810615   0.946114                            7,12-dimethyltetraphene
# 12132768  0.945424                                      dexamethasone
# 5537823   0.944820                                 copper(II) sulfate
# 12979602  0.944526                                             arsane
# 10357415  0.943362                                  nickel dichloride
# 7846571   0.942933                                    silicon dioxide
# 3275131   0.941230                            all-trans-retinoic acid
# 6659824   0.940859                                          genistein
# 2107499   0.940656                                          camazepam
# 10670639  0.939653                          1-naphthyl isothiocyanate
# 38663771  0.938606       lipopolysaccharide, Escherichia coli O111 B4
# 10675889  0.938015                                 cadmium dichloride
#
#                                                  bp
# 9417941                regulation of blood pressure
# 8467967                           apoptotic process
# 7684907                           apoptotic process
# 46146403                    lipid catabolic process
# 3557423                           apoptotic process
# 13171379                          apoptotic process
# 8149897                      cellular proliferation
# 22795439                          apoptotic process
# 11888791                    lipid catabolic process
# 34788887                          apoptotic process
# 9241129                      cellular proliferation
# 3876319                     lipid catabolic process
# 45115175                          apoptotic process
# 7614652           positive regulation of cell death
# 43200665               regulation of blood pressure
# 3926425                      cellular proliferation
# 10130274                                 cell death
# 22431695                          apoptotic process
# 12661325               regulation of blood pressure
# 24407027                          apoptotic process
# 45019393                     cellular proliferation
# 3259561                      cellular proliferation
# 7559275                              cell migration
# 12332946                                 cell death
# 44842573                     cellular proliferation
# 7417358   positive regulation of cell proliferation
# 6679559                           apoptotic process
# 9251027                           apoptotic process
# 17900249               regulation of blood pressure
# 25892521                     cellular proliferation
# 4280058                                  cell death
# 3183575                           apoptotic process
# 46034845                     cellular proliferation
# 7861925                regulation of blood pressure
# 7028353                      cellular proliferation
# 43205718                                 cell death
# 2764259                           apoptotic process
# 23573486                                 cell cycle
# 5810615                           apoptotic process
# 12132768           membrane lipid catabolic process
# 5537823                response to oxidative stress
# 12979602                                 cell death
# 10357415                          apoptotic process
# 7846571                           apoptotic process
# 3275131                     lipid catabolic process
# 6659824           positive regulation of cell death
# 2107499                           apoptotic process
# 10670639                          apoptotic process
# 38663771                          apoptotic process
# 10675889               regulation of blood pressure

# %%
pairs.query('status == 0').drop_duplicates(subset=['biologicalprocessoractivity_id']).head(50)
# Out:
#          chemicalsubstance_id biologicalprocessoractivity_id  status  \
# 9417941           CHEBI:33216                     GO:0008217       0
# 8467967           CHEBI:31580                     GO:0006915       0
# 9419386           CHEBI:33216                     GO:0042310       0
# 9417598           CHEBI:33216                     GO:0006309       0
# 46146403      UNII:OHF2F5C0ZH                     GO:0016042       0
# 9418687           CHEBI:33216                     GO:0030154       0
# 9419387           CHEBI:33216                     GO:0042311       0
# 8468166           CHEBI:31580                     GO:0008219       0
# 8149897           CHEBI:31206                     GO:0008283       0
# 46145739  0.947172  Tetrachlorodibenzodioxin
# 9416961   0.946601               bisphenol A
# 23573486  0.946136                 robinetin
# 43203607  0.945881              Dietary Fats
# 5537823   0.944820        copper(II) sulfate
# 7617923   0.942971            benzo[a]pyrene
# 46147499  0.942151  Tetrachlorodibenzodioxin
# 9416951   0.940803               bisphenol A
# 9420824   0.940628               bisphenol A
# 46147120  0.939292  Tetrachlorodibenzodioxin
# 46146404  0.938920  Tetrachlorodibenzodioxin
# 9418463   0.937435               bisphenol A
# 9417752   0.934430               bisphenol A
# 46145501  0.933711  Tetrachlorodibenzodioxin
# 9421045   0.933539               bisphenol A
# 9419863   0.933365               bisphenol A
# 9420646   0.931094               bisphenol A
# 9420361   0.930678               bisphenol A
# 43200675  0.929910              Dietary Fats
# 46145738  0.929626  Tetrachlorodibenzodioxin
# 9421280   0.929296               bisphenol A
# 7614989   0.929097            benzo[a]pyrene
# 9418747   0.927925               bisphenol A
# 46145723  0.926820  Tetrachlorodibenzodioxin
# 9417530   0.926556               bisphenol A
# 9420466   0.926295               bisphenol A
# 7558850   0.925632           sodium arsenite
# 9420333   0.924628               bisphenol A
# 46145752  0.922869  Tetrachlorodibenzodioxin
# 7558564   0.922189           sodium arsenite
#
#                                                          bp
# 9417941                        regulation of blood pressure
# 8467967                                   apoptotic process
# 9419386                                    vasoconstriction
# 9417598                         apoptotic DNA fragmentation
# 46146403                            lipid catabolic process
# 9418687                                cell differentiation
# 9419387                                        vasodilation
# 8468166                                          cell death
# 8149897                              cellular proliferation
# 11888378          positive regulation of cell proliferation
# 9417112                            regulation of heart rate
# 7614652                   positive regulation of cell death
# 9417684                    cholesterol biosynthetic process
# 7559275                                      cell migration
# 46149523       reactive oxygen species biosynthetic process
# 9417742                                           autophagy
# 9417714                                       ion transport
# 9418581                          calcium-mediated signaling
# 7616280                    membrane lipid catabolic process
# 11889922           positive regulation of apoptotic process
# 46145739                   glutathione biosynthetic process
# 9416961                                  mitotic cell cycle
# 23573486                                         cell cycle
# 43203607          reactive oxygen species metabolic process
# 5537823                        response to oxidative stress
# 7617923   positive regulation of reactive oxygen species...
# 46147499       DNA damage response, detection of DNA damage
# 9416951                                        MAPK cascade
# 9420824                           mitotic cell cycle arrest
# 46147120                                    lipid oxidation
# 46146404                                        cell growth
# 9418463                              drug metabolic process
# 9417752                               inflammatory response
# 46145501                      superoxide dismutase activity
# 9421045      histamine secretion mediated by immunoglobulin
# 9419863                          regulation of organ growth
# 9420646        positive regulation of ERK1 and ERK2 cascade
# 9420361                   excitatory postsynaptic potential
# 43200675          negative regulation of cell proliferation
# 46145738                      glutathione metabolic process
# 9421280      positive regulation of NIK/NF-kappaB signaling
# 7614989                   triglyceride biosynthetic process
# 9418747                                leukocyte chemotaxis
# 46145723                       steroid biosynthetic process
# 9417530                          glycogen catabolic process
# 9420466                          adipose tissue development
# 7558850                          lipid biosynthetic process
# 9420333                         oxidation-reduction process
# 46145752                  nitric oxide biosynthetic process
# 7558564                            ATP biosynthetic process
